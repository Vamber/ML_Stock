# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 200

# %%
base_path = "/home/vamber/ML_stock/Data/Feature/ASML/Raw_Features/Google_Trends/ASML stock/"
df_dates_path = base_path + "dates_downloaded.csv"
df_dates = pd.read_csv(df_dates_path)

# %%
dates = list(df_dates["dates"])

# %%
dates
# Out:
# ['2021-10-11',
#  '2021-10-12',
#  '2021-10-13',
#  '2021-10-14',
#  '2021-10-15',
#  '2021-10-16',
#  '2021-10-17',
#  '2021-10-18',
#  '2021-10-19',
#  '2021-10-20',
#  '2021-10-21',
#  '2021-10-22',
#  '2021-10-23',
#  '2021-10-24',
#  '2021-10-25',
#  '2021-10-26',
#  '2021-10-27',
#  '2021-10-28',
#  '2021-10-29',
#  '2021-10-30',
#  '2021-10-31',
#  '2021-11-01',
#  '2021-11-02',
#  '2021-11-03',
#  '2021-11-04',
#  '2021-11-05',
#  '2021-11-06',
#  '2021-11-07',
#  '2021-11-08',
#  '2021-11-09',
#  '2021-11-10',
#  '2021-11-11',
#  '2021-11-12',
#  '2021-11-13',
#  '2021-11-14',
#  '2021-11-15',
#  '2021-11-16',
#  '2021-11-17',
#  '2021-11-18',
#  '2021-11-19',
#  '2021-11-20',
#  '2021-11-21',
#  '2021-11-22',
#  '2021-11-23',
#  '2021-11-24',
#  '2021-11-25',
#  '2021-11-26',
#  '2021-11-27',
#  '2021-11-28',
#  '2021-11-29',
#  '2021-11-30',
#  '2021-12-01',
#  '2021-12-02',
#  '2021-12-03',
#  '2021-12-04',
#  '2021-12-05',
#  '2021-12-06',
#  '2021-12-07']

# %%
dfs = []
for i in range(10,17):
    df = pd.read_csv(base_path + dates[i] + ".csv")
    dfs.append(df)

# %%
for df in dfs:
    df.drop("isPartial",inplace=True, axis=1)
    df["date"] = df["date"].apply(lambda x : str(x)[5:15])

# %%
#this is a collection of 7 consecutive datas
dfs[2]
# Out:
#            date  ASML stock
# 0    10-17 00:0          11
# 1    10-17 01:0          14
# 2    10-17 02:0           7
# 3    10-17 03:0          10
# 4    10-17 04:0          10
# ..          ...         ...
# 163  10-23 19:0           2
# 164  10-23 20:0           8
# 165  10-23 21:0           7
# 166  10-23 22:0           5
# 167  10-23 23:0           4
#
# [168 rows x 2 columns]

# %%
i = 0
plt.figure(figsize=(24,6))
ax = plt.axes()

plt.plot(dfs[i]["date"], dfs[i]["ASML stock"])

plt.xticks(dfs[i]["date"][::5], rotation = "vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x7fefecd187b8>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df_merge = dfs[0]

for df_i in dfs:
 df_merge = pd.merge(df_merge, df_i, how="outer", on=["date"])

# %%
df_merge.set_axis(["date",0,1,2,3,4,5,6,7], inplace=True, axis=1)

# %%
df = df_merge

df.set_index("date").plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dfs[0]
# Out:
#            date  ASML stock
# 0    10-15 00:0          15
# 1    10-15 01:0          13
# 2    10-15 02:0          15
# 3    10-15 03:0          17
# 4    10-15 04:0          18
# ..          ...         ...
# 163  10-21 19:0          33
# 164  10-21 20:0          30
# 165  10-21 21:0          18
# 166  10-21 22:0          25
# 167  10-21 23:0          16
#
# [168 rows x 2 columns]

# %%
dfs[6]
# Out:
#            date  ASML stock
# 0    10-21 00:0          39
# 1    10-21 01:0          41
# 2    10-21 02:0          36
# 3    10-21 03:0          50
# 4    10-21 04:0          47
# ..          ...         ...
# 163  10-27 19:0          34
# 164  10-27 20:0          28
# 165  10-27 21:0          22
# 166  10-27 22:0          21
# 167  10-27 23:0          21
#
# [168 rows x 2 columns]

# %%
first_last_merge = pd.merge(dfs[0], dfs[6], how="inner", on="date")

# %%
first_last_merge
# Out:
#           date  ASML stock_x  ASML stock_y
# 0   10-21 00:0            26            39
# 1   10-21 01:0            27            41
# 2   10-21 02:0            24            36
# 3   10-21 03:0            33            50
# 4   10-21 04:0            32            47
# 5   10-21 05:0            27            40
# 6   10-21 06:0            28            42
# 7   10-21 07:0            15            22
# 8   10-21 08:0            10            16
# 9   10-21 09:0            34            51
# 10  10-21 10:0            53            79
# 11  10-21 11:0            39            59
# 12  10-21 12:0            39            59
# 13  10-21 13:0            67           100
# 14  10-21 14:0            48            73
# 15  10-21 15:0            37            55
# 16  10-21 16:0            35            53
# 17  10-21 17:0            30            45
# 18  10-21 18:0            31            47
# 19  10-21 19:0            33            49
# 20  10-21 20:0            30            44
# ...

# %%
ratio = np.mean(first_last_merge["ASML stock_x"]/first_last_merge["ASML stock_y"])
ratio
# Out:
# 0.6675397737628569

# %%
inter_date = first_last_merge["date"][0]

# %%
first_last_merge_outer = pd.merge(dfs[0], dfs[6], how="outer", on="date")

# %%
first_last_merge_outer
# Out:
#            date  ASML stock_x  ASML stock_y
# 0    10-15 00:0          15.0           NaN
# 1    10-15 01:0          13.0           NaN
# 2    10-15 02:0          15.0           NaN
# 3    10-15 03:0          17.0           NaN
# 4    10-15 04:0          18.0           NaN
# ..          ...           ...           ...
# 307  10-27 19:0           NaN          34.0
# 308  10-27 20:0           NaN          28.0
# 309  10-27 21:0           NaN          22.0
# 310  10-27 22:0           NaN          21.0
# 311  10-27 23:0           NaN          21.0
#
# [312 rows x 3 columns]

# %%
before = first_last_merge_outer[ first_last_merge_outer["date"] < inter_date]

# %%
before
# Out:
#            date  ASML stock_x  ASML stock_y
# 0    10-15 00:0          15.0           NaN
# 1    10-15 01:0          13.0           NaN
# 2    10-15 02:0          15.0           NaN
# 3    10-15 03:0          17.0           NaN
# 4    10-15 04:0          18.0           NaN
# ..          ...           ...           ...
# 139  10-20 19:0          48.0           NaN
# 140  10-20 20:0          53.0           NaN
# 141  10-20 21:0          39.0           NaN
# 142  10-20 22:0          35.0           NaN
# 143  10-20 23:0          33.0           NaN
#
# [144 rows x 3 columns]

# %%
after = first_last_merge_outer[ first_last_merge_outer["date"] >= inter_date]

# %%
after
# Out:
#            date  ASML stock_x  ASML stock_y
# 144  10-21 00:0          26.0          39.0
# 145  10-21 01:0          27.0          41.0
# 146  10-21 02:0          24.0          36.0
# 147  10-21 03:0          33.0          50.0
# 148  10-21 04:0          32.0          47.0
# ..          ...           ...           ...
# 307  10-27 19:0           NaN          34.0
# 308  10-27 20:0           NaN          28.0
# 309  10-27 21:0           NaN          22.0
# 310  10-27 22:0           NaN          21.0
# 311  10-27 23:0           NaN          21.0
#
# [168 rows x 3 columns]

# %%
standardized_trend_array = pd.concat([before["ASML stock_x"]/ratio, after["ASML stock_y"]])

# %%
first_last_merge_outer["std_score"] = standardized_trend_array

# %%
first_last_merge_outer
# Out:
#            date  ASML stock_x  ASML stock_y  std_score
# 0    10-15 00:0          15.0           NaN  22.470571
# 1    10-15 01:0          13.0           NaN  19.474495
# 2    10-15 02:0          15.0           NaN  22.470571
# 3    10-15 03:0          17.0           NaN  25.466647
# 4    10-15 04:0          18.0           NaN  26.964685
# ..          ...           ...           ...        ...
# 307  10-27 19:0           NaN          34.0  34.000000
# 308  10-27 20:0           NaN          28.0  28.000000
# 309  10-27 21:0           NaN          22.0  22.000000
# 310  10-27 22:0           NaN          21.0  21.000000
# 311  10-27 23:0           NaN          21.0  21.000000
#
# [312 rows x 4 columns]

# %%
first_last_merge_outer.set_index("date").plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dates = first_last_merge_outer["date"].apply(lambda x: x[0:5]).unique()

# %%
i = 4
df_1 = first_last_merge_outer[ (first_last_merge_outer["date"]>= dates[i]) & (first_last_merge_outer["date"] <= dates[i+7]) ]
df_1 = df_1.copy()
max_v = max(df_1["std_score"])
df_1["nor_score"] = df_1["std_score"]/(max_v/100)

# %%
df_1
# Out:
#            date  ASML stock_x  ASML stock_y  std_score  nor_score
# 96   10-19 00:0          12.0           NaN  17.976457  12.000000
# 97   10-19 01:0          23.0           NaN  34.454876  23.000000
# 98   10-19 02:0          18.0           NaN  26.964685  18.000000
# 99   10-19 03:0          18.0           NaN  26.964685  18.000000
# 100  10-19 04:0          19.0           NaN  28.462723  19.000000
# ..          ...           ...           ...        ...        ...
# 259  10-25 19:0           NaN          42.0  42.000000  28.036670
# 260  10-25 20:0           NaN          40.0  40.000000  26.701591
# 261  10-25 21:0           NaN          27.0  27.000000  18.023574
# 262  10-25 22:0           NaN          21.0  21.000000  14.018335
# 263  10-25 23:0           NaN          19.0  19.000000  12.683256
#
# [168 rows x 5 columns]

# %%
dfs[4]
# Out:
#            date  ASML stock
# 0    10-19 00:0          12
# 1    10-19 01:0          23
# 2    10-19 02:0          18
# 3    10-19 03:0          18
# 4    10-19 04:0          19
# ..          ...         ...
# 163  10-25 19:0          28
# 164  10-25 20:0          27
# 165  10-25 21:0          18
# 166  10-25 22:0          14
# 167  10-25 23:0          12
#
# [168 rows x 2 columns]

# %%
dates = list(df_dates["dates"])

# %%
test_dfs = []
for i in range(0,30):
    df = pd.read_csv(base_path + dates[i] + ".csv")
    test_dfs.append(df)

# %%
A = test_dfs[13]

# %%
B = test_dfs[19]

# %%
#There is no need to call this function at all
#If the last two days downloaded are adject (it's actually a clever exercise to prove why this is true)


def generate_missing_google_trend_df_using_two_dfs_a_week_apart(left_df, right_df):
    #left_df, eg. a google trend score df containing dates from 10-15 -> 10-21 
    #right_df, eg. a google trend score df containing dates from 10-21 -> 10-27
    #and the goal is to generate every single missing df in between them

    #extract the keyword
    keyword = left_df.columns[1]

    #getting the date, and MOST important, finding the conversation ratio constant 
    overlap_time_df = pd.merge(left_df, right_df, how="inner", on="date")
    overlap_time = overlap_time_df["date"][0]
    std_conversion_ratio = np.mean(overlap_time_df[keyword+"_x"] / overlap_time_df[keyword+"_y"])
    print(std_conversion_ratio)



    outer_merge_df = pd.merge(left_df, right_df, how="outer", on="date")

    #this is every single day in short form in both left_df and right_df
    #it should look something like ['2021-10-15', '2021-10-16' ... '2021-10-27' ]
    the_13_days = outer_merge_df["date"].apply(lambda x : x.split(" ")[0]).unique()
    assert len(the_13_days) == 13, "the two dfs are not a week apart, violating function assumption, abort"

    #This is the df that's before the intersection of the two table
    #We want standardize the date's trend score into right_df measuring system
    before_df = outer_merge_df[outer_merge_df["date"] < overlap_time]
    std_trend_score_array = before_df[keyword + '_x']/std_conversion_ratio

    after_df = outer_merge_df[outer_merge_df["date"] >= overlap_time]
    og_trend_score_array = after_df[keyword + "_y"]
    
    entire_std_trend_score_array = pd.concat([std_trend_score_array, og_trend_score_array])

    #add to outer merge
    outer_merge_df["std_score"] = entire_std_trend_score_array


    #returns a dictonary of dates+dictionary pair
    #and we are generating 5 dfs, you can go count it
    result = {}
    for i in range(1,6):
        begin_date = the_13_days[i]
        df_name = the_13_days[i+6]
        end_date = the_13_days[i+7]
        df_i = outer_merge_df[(outer_merge_df["date"] >= begin_date) & (outer_merge_df["date"] <= end_date)][["date", "std_score"]]
        #clone is needed, since the above is only a view
        df_i = df_i.copy()
        df_i[keyword] = round((df_i["std_score"]/(max(df_i["std_score"])/100)), 0)
        df_i = df_i [["date", keyword]]
        result[df_name] = df_i

    return result

# %%
r = generate_missing_google_trend_df_using_two_dfs_a_week_apart(A, B)
# Out:
# 0.4288243684579757

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-0c6a1e9c4efe> in <module>
# ----> 1 r[1]
#
# KeyError: 1

# %%
list(r.values())[4]
# Out:
#                     date  ASML stock
# 120  2021-10-23 00:00:00        23.0
# 121  2021-10-23 01:00:00        28.0
# 122  2021-10-23 02:00:00        23.0
# 123  2021-10-23 03:00:00        23.0
# 124  2021-10-23 04:00:00        23.0
# ..                   ...         ...
# 283  2021-10-29 19:00:00        42.0
# 284  2021-10-29 20:00:00        36.0
# 285  2021-10-29 21:00:00        15.0
# 286  2021-10-29 22:00:00        39.0
# 287  2021-10-29 23:00:00        29.0
#
# [168 rows x 2 columns]

# %%
test_dfs[18]
# Out:
#                     date  ASML stock  isPartial
# 0    2021-10-23 00:00:00          24      False
# 1    2021-10-23 01:00:00          27      False
# 2    2021-10-23 02:00:00          23      False
# 3    2021-10-23 03:00:00          24      False
# 4    2021-10-23 04:00:00          23      False
# ..                   ...         ...        ...
# 163  2021-10-29 19:00:00          42      False
# 164  2021-10-29 20:00:00          36      False
# 165  2021-10-29 21:00:00          15      False
# 166  2021-10-29 22:00:00          39      False
# 167  2021-10-29 23:00:00          29      False
#
# [168 rows x 3 columns]
