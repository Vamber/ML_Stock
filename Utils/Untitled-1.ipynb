# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 200

# %%
df =  pd.read_csv("/home/vamber/ML_stock/Utils/nvidia_trend.csv", engine="python")

# %%
df["date"] = df["date"].apply(lambda x : str(x)[5:15])
df
# Out:
#      Unnamed: 0        date  Buy Nvidia  isPartial         day
# 0             0  10-03 01:0           7      False  2019-10-03
# 1             1  10-03 02:0           6      False  2019-10-03
# 2             2  10-03 03:0           9      False  2019-10-03
# 3             3  10-03 04:0          13      False  2019-10-03
# 4             4  10-03 05:0           8      False  2019-10-03
# ..          ...         ...         ...        ...         ...
# 162         162  10-09 19:0          11      False  2019-10-09
# 163         163  10-09 20:0           9      False  2019-10-09
# 164         164  10-09 21:0           9      False  2019-10-09
# 165         165  10-09 22:0           7      False  2019-10-09
# 166         166  10-09 23:0           7      False  2019-10-09
#
# [167 rows x 5 columns]

# %%
plt.figure(figsize=(24,6))
ax = plt.axes()

plt.plot(df["date"], df["Elon Musk"])

plt.xticks(df["date"][::5], rotation = "vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x7ff1fdf5a710>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df
# Out:
#      Unnamed: 0        date  Buy Nvidia  isPartial         day
# 0             0  10-03 01:0           7      False  2019-10-03
# 1             1  10-03 02:0           6      False  2019-10-03
# 2             2  10-03 03:0           9      False  2019-10-03
# 3             3  10-03 04:0          13      False  2019-10-03
# 4             4  10-03 05:0           8      False  2019-10-03
# ..          ...         ...         ...        ...         ...
# 162         162  10-09 19:0          11      False  2019-10-09
# 163         163  10-09 20:0           9      False  2019-10-09
# 164         164  10-09 21:0           9      False  2019-10-09
# 165         165  10-09 22:0           7      False  2019-10-09
# 166         166  10-09 23:0           7      False  2019-10-09
#
# [167 rows x 5 columns]

# %%
df_1 = df.groupby("day").max()

# %%
df_1
# Out:
#             Unnamed: 0        date  Buy Nvidia  isPartial
# day
# 2019-10-03          22  10-03 23:0          19      False
# 2019-10-04          46  10-04 23:0          34      False
# 2019-10-05          70  10-05 23:0         100      False
# 2019-10-06          94  10-06 23:0          18      False
# 2019-10-07         118  10-07 23:0          20      False
# 2019-10-08         142  10-08 23:0          22      False
# 2019-10-09         166  10-09 23:0          24      False
