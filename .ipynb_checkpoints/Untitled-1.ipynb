# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 200

# %%
df =  pd.read_csv("/home/vamber/ML_stock/Utils/RTX_3090.csv", engine="python")
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/lib64/python3.6/site-packages/pandas/io/parsers.py in _infer_columns(self)
#    2684                 try:
# -> 2685                     line = self._buffered_line()
#    2686
#
# /usr/local/lib64/python3.6/site-packages/pandas/io/parsers.py in _buffered_line(self)
#    2860         else:
# -> 2861             return self._next_line()
#    2862
#
# /usr/local/lib64/python3.6/site-packages/pandas/io/parsers.py in _next_line(self)
#    2957             while True:
# -> 2958                 orig_line = self._next_iter_line(row_num=self.pos + 1)
#    2959                 self.pos += 1
#
# /usr/local/lib64/python3.6/site-packages/pandas/io/parsers.py in _next_iter_line(self, row_num)
#    3015         try:
# -> 3016             return next(self.data)
#    3017         except csv.Error as e:
#
# StopIteration:
#
# ...

# %%
df["date"] = df["date"].apply(lambda x : str(x)[5:15])
df
# Out:
#            date  buy Netflix stock  isPartial
# 0    10-10 00:0                 12      False
# 1    10-10 01:0                 12      False
# 2    10-10 02:0                 13      False
# 3    10-10 03:0                 36      False
# 4    10-10 04:0                 19      False
# ..          ...                ...        ...
# 151  10-16 07:0                 23      False
# 152  10-16 08:0                 57      False
# 153  10-16 09:0                 29      False
# 154  10-16 10:0                 41      False
# 155  10-16 11:0                 20       True
#
# [156 rows x 3 columns]

# %%
plt.figure(figsize=(24,6))
ax = plt.axes()

plt.plot(df["date"], df["buy Netflix stock"])

plt.xticks(df["date"][::5], rotation = "vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x7fbf018324e0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df =  pd.read_csv("/home/vamber/ML_stock/Utils/RTX_3090.csv", engine="python")

# %%
df
# Out:
#                     date  buy Netflix stock  isPartial
# 0    2021-07-26 00:00:00                 21      False
# 1    2021-07-26 01:00:00                 35      False
# 2    2021-07-26 02:00:00                 30      False
# 3    2021-07-26 03:00:00                 36      False
# 4    2021-07-26 04:00:00                 35      False
# ..                   ...                ...        ...
# 163  2021-08-01 19:00:00                 21      False
# 164  2021-08-01 20:00:00                  7      False
# 165  2021-08-01 21:00:00                  7      False
# 166  2021-08-01 22:00:00                 21      False
# 167  2021-08-01 23:00:00                 34      False
#
# [168 rows x 3 columns]

# %%
df["only_day"] = df["date"].apply(lambda s: s.split(" ")[0])
df = df.groupby("only_day").max()
list(df["buy Netflix stock"])
# Out:
# [100, 93, 70, 87, 91, 54, 67]
